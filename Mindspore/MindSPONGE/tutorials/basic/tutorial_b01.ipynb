# %%
import numpy as np
from mindspore import context
from mindsponge import Sponge
from mindsponge import Molecule
from mindsponge import ForceFieldBase
from mindsponge import DynamicUpdater

from mindsponge.potential import BondEnergy, AngleEnergy
from mindsponge.callback import WriteH5MD, RunInfo
from mindsponge.function import VelocityGenerator
from mindsponge.control import LeapFrog, BerendsenThermostat

# %% [markdown]
# ## 图模式选择与GPU选择
#
# 一般情况下，使用MindSpore的静态图模式GRAPH_MODE会取得更好的速度增益，而动态图模式PYNATIVE_MODE更多的被用于进行Debug。在硬件平台上，如果没有华为的Ascend专用硬件，一般都是在GPU上运行，才有一定的速度保障。如果有多张卡，可以通过device_id进行选择。

# %%
context.set_context(mode=context.GRAPH_MODE, device_target="GPU")

# %% [markdown]
# ## 创建分子对象
#
# 一个分子，可以是三个原子组成的水分子，也可以是上万个原子组成的蛋白质。在MindSponge中，为不同类型的分子提供了多种定义形式。当定义一个小体系$H_2O$时，我们可以直接用常规的列表来定义分子中所包含的原子种类、原子坐标以及键连信息等。在后续的案例中我们也会讲到，还可以通过配置文件等方式来进行定义，这两种方式都是支持的。

# %%
system = Molecule(atoms=['O', 'H', 'H'],
                  coordinate=[[0, 0, 0], [0.1, 0, 0], [-0.0333, 0.0943, 0]],
                  bond=[[[0, 1], [0, 2]]])

# %% [markdown]
# ## 能量项定义
#
# 不同的分子体系会有不同的能量项的需求。比如当前定义的$H_2O$分子，因为只有3个原子，因此涉及到的能量项只有近程相互作用中的键相互作用和角相互作用：
#
# $$
# E_{bond}=\frac{1}{2}k_b(l-l_0)^2\\
# E_{angle}=\frac{1}{2}k_a(a-a_0)^2
# $$

# %%
bond_energy = BondEnergy(index=system.bond,
                         force_constant=[[345000, 345000]],
                         bond_length=[[0.1, 0.1]])

# %%
angle_energy = AngleEnergy(index=[[1, 0, 2]],
                           force_constant=[[383]],
                           bond_angle=[[109.47 / 180 * np.pi]])

# %%
potential = ForceFieldBase(energy=[bond_energy, angle_energy])

# %% [markdown]
# ## 速度生成器
#
# 根据指定的温度，我们可以计算出系统平均运动动能，进而通过标准正态分布生成随机的一组原子运动速度，用于初始化系统。

# %%
vgen = VelocityGenerator(300)
velocity = vgen(system.coordinate.shape, system.atom_mass)
# Out:
# TotalTime = 0.157032, [19]
# [parse]: 0.0221374
# [symbol_resolve]: 0.0702502, [1]
#     [Cycle 1]: 0.0697669, [1]
#         [resolve]: 0.0697553
# [combine_like_graphs]: 2.66545e-06
# [inference_opt_prepare]: 0.000401873
# [abstract_specialize]: 0.0494782
# [auto_monad]: 0.000281934
# [inline]: 6.17094e-06
# [py_pre_ad]: 1.46404e-06
# [pynative_shard]: 3.58559e-06
# [pipeline_split]: 4.88199e-06
# [optimize]: 0.00598948, [15]
#     [simplify_data_structures]: 0.00013376
#     [opt_a]: 0.00518617, [2]
#         [Cycle 1]: 0.00425204, [25]
#             [expand_dump_flag]: 5.26011e-06
#             [switch_simplify]: 0.00027016
#             [a_1]: 0.00186183
#             [recompute_prepare]: 7.12462e-06
#             [updatestate_depend_eliminate]: 1.08667e-05
#             [updatestate_assign_eliminate]: 8.59797e-06
#             [updatestate_loads_eliminate]: 8.48807e-06
#             [parameter_eliminate]: 3.05101e-06
#             [a_2]: 0.000274925
#             [accelerated_algorithm]: 6.96629e-06
#             [auto_parallel]: 4.67338e-06
#             [parallel]: 6.0536e-06
#             [allreduce_fusion]: 7.63126e-06
#             [virtual_dataset]: 7.29226e-06
#             [virtual_output]: 7.31461e-06
#             [shard]: 8.18074e-06
#             [meta_fg_expand]: 1.14031e-05
#             [after_resolve]: 8.32602e-06
#             [a_after_grad]: 8.56072e-06
#             [renormalize]: 0.00146746
#             [real_op_eliminate]: 9.49949e-06
#             [auto_monad_grad]: 5.4799e-06
#             [auto_monad_eliminator]: 2.38549e-05
#             [cse]: 8.76281e-05
#             [a_3]: 8.32155e-05
#         [Cycle 2]: 0.000505822, [25]
#             [expand_dump_flag]: 8.34465e-07
#             [switch_simplify]: 7.13579e-06
#             [a_1]: 0.000107778
#             [recompute_prepare]: 4.92483e-06
#             [updatestate_depend_eliminate]: 5.9884e-06
#             [updatestate_assign_eliminate]: 5.14463e-06
#             [updatestate_loads_eliminate]: 5.06639e-06
#             [parameter_eliminate]: 1.02073e-06
#             [a_2]: 0.00011724
#             [accelerated_algorithm]: 6.69993e-06
#             [auto_parallel]: 2.17184e-06
#             [parallel]: 1.57952e-06
#             [allreduce_fusion]: 3.87244e-06
#             [virtual_dataset]: 6.9961e-06
#             [virtual_output]: 6.70739e-06
#             [shard]: 6.41122e-06
#             [meta_fg_expand]: 1.07046e-05
#             [after_resolve]: 6.56955e-06
#             [a_after_grad]: 8.40239e-06
#             [renormalize]: 2.01166e-07
#             [real_op_eliminate]: 6.74836e-06
#             [auto_monad_grad]: 8.40053e-07
#             [auto_monad_eliminator]: 3.97321e-05
#             [cse]: 2.39369e-05
#             [a_3]: 8.65292e-05
#     [clean_after_opta]: 2.75299e-05
#     [opt_b]: 0.000246212, [1]
#         [Cycle 1]: 0.000242574, [7]
#             [b_1]: 0.000188507
#             [b_2]: 7.4245e-06
#             [updatestate_depend_eliminate]: 5.87292e-06
#             [updatestate_assign_eliminate]: 5.02169e-06
#             [updatestate_loads_eliminate]: 5.01052e-06
#             [renormalize]: 3.89293e-07
#             [cse]: 2.13329e-05
#     [cconv]: 1.95969e-05
#     [opt_after_cconv]: 6.35181e-05, [1]
#         [Cycle 1]: 6.07986e-05, [6]
#             [c_1]: 1.87084e-05
#             [updatestate_depend_eliminate]: 5.1707e-06
#             [updatestate_assign_eliminate]: 4.90062e-06
#             [updatestate_loads_eliminate]: 4.9565e-06
#             [cse]: 1.90437e-05
#             [renormalize]: 2.62633e-07
#     [remove_dup_value]: 9.44007e-05
#     [tuple_transform]: 4.04436e-05, [1]
#         [Cycle 1]: 3.77037e-05, [2]
#             [d_1]: 3.5096e-05
#             [renormalize]: 2.44007e-07
#     [add_cache_embedding]: 1.40332e-05
#     [add_recomputation]: 7.41817e-05
#     [cse_after_recomputation]: 2.34954e-05, [1]
#         [Cycle 1]: 2.09641e-05, [1]
#             [cse]: 1.9446e-05
#     [environ_conv]: 1.60001e-05
#     [slice_recompute_activation]: 4.22262e-06
#     [comm_op_add_attrs]: 5.88596e-07
#     [add_comm_op_reuse_tag]: 1.40257e-06
# [py_opt]: 1.00769e-06
# [auto_monad_reorder]: 3.53213e-05
# [eliminate_forward_cnode]: 1.72481e-06
# [eliminate_ad_related_special_op_node]: 0.000236485
# [validate]: 3.279e-05
# [distribtued_split]: 6.70552e-07
# [task_emit]: 0.00804696
# [execute]: 6.49504e-06
# Sums
#     parse                                :     0.022137s : 14.21%
#     symbol_resolve.resolve               :     0.069755s : 44.76%
#     combine_like_graphs                  :     0.000003s :  0.00%
#     inference_opt_prepare                :     0.000402s :  0.26%
#     abstract_specialize                  :     0.049478s : 31.75%
#     auto_monad                           :     0.000282s :  0.18%
#     inline                               :     0.000006s :  0.00%
#     py_pre_ad                            :     0.000001s :  0.00%
#     pynative_shard                       :     0.000004s :  0.00%
#     pipeline_split                       :     0.000005s :  0.00%
#     optimize.simplify_data_structures    :     0.000134s :  0.09%
#     optimize.opt_a.expand_dump_flag      :     0.000006s :  0.00%
#     optimize.opt_a.switch_simplify       :     0.000277s :  0.18%
#     optimize.opt_a.a_1                   :     0.001970s :  1.26%
#     optimize.opt_a.recompute_prepare     :     0.000012s :  0.01%
#     optimize.opt_a.updatestate_depend_eliminate :     0.000017s :  0.01%
#     optimize.opt_a.updatestate_assign_eliminate :     0.000014s :  0.01%
#     optimize.opt_a.updatestate_loads_eliminate :     0.000014s :  0.01%
#     optimize.opt_a.parameter_eliminate   :     0.000004s :  0.00%
#     optimize.opt_a.a_2                   :     0.000392s :  0.25%
#     optimize.opt_a.accelerated_algorithm :     0.000014s :  0.01%
#     optimize.opt_a.auto_parallel         :     0.000007s :  0.00%
#     optimize.opt_a.parallel              :     0.000008s :  0.00%
#     optimize.opt_a.allreduce_fusion      :     0.000012s :  0.01%
#     optimize.opt_a.virtual_dataset       :     0.000014s :  0.01%
#     optimize.opt_a.virtual_output        :     0.000014s :  0.01%
#     optimize.opt_a.shard                 :     0.000015s :  0.01%
#     optimize.opt_a.meta_fg_expand        :     0.000022s :  0.01%
#     optimize.opt_a.after_resolve         :     0.000015s :  0.01%
#     optimize.opt_a.a_after_grad          :     0.000017s :  0.01%
#     optimize.opt_a.renormalize           :     0.001468s :  0.94%
#     optimize.opt_a.real_op_eliminate     :     0.000016s :  0.01%
#     optimize.opt_a.auto_monad_grad       :     0.000006s :  0.00%
#     optimize.opt_a.auto_monad_eliminator :     0.000064s :  0.04%
#     optimize.opt_a.cse                   :     0.000112s :  0.07%
#     optimize.opt_a.a_3                   :     0.000170s :  0.11%
#     optimize.clean_after_opta            :     0.000028s :  0.02%
#     optimize.opt_b.b_1                   :     0.000189s :  0.12%
#     optimize.opt_b.b_2                   :     0.000007s :  0.00%
#     optimize.opt_b.updatestate_depend_eliminate :     0.000006s :  0.00%
#     optimize.opt_b.updatestate_assign_eliminate :     0.000005s :  0.00%
#     optimize.opt_b.updatestate_loads_eliminate :     0.000005s :  0.00%
#     optimize.opt_b.renormalize           :     0.000000s :  0.00%
#     optimize.opt_b.cse                   :     0.000021s :  0.01%
#     optimize.cconv                       :     0.000020s :  0.01%
#     optimize.opt_after_cconv.c_1         :     0.000019s :  0.01%
#     optimize.opt_after_cconv.updatestate_depend_eliminate :     0.000005s :  0.00%
#     optimize.opt_after_cconv.updatestate_assign_eliminate :     0.000005s :  0.00%
#     optimize.opt_after_cconv.updatestate_loads_eliminate :     0.000005s :  0.00%
#     optimize.opt_after_cconv.cse         :     0.000019s :  0.01%
#     optimize.opt_after_cconv.renormalize :     0.000000s :  0.00%
#     optimize.remove_dup_value            :     0.000094s :  0.06%
#     optimize.tuple_transform.d_1         :     0.000035s :  0.02%
#     optimize.tuple_transform.renormalize :     0.000000s :  0.00%
#     optimize.add_cache_embedding         :     0.000014s :  0.01%
#     optimize.add_recomputation           :     0.000074s :  0.05%
#     optimize.cse_after_recomputation.cse :     0.000019s :  0.01%
#     optimize.environ_conv                :     0.000016s :  0.01%
#     optimize.slice_recompute_activation  :     0.000004s :  0.00%
#     optimize.comm_op_add_attrs           :     0.000001s :  0.00%
#     optimize.add_comm_op_reuse_tag       :     0.000001s :  0.00%
#     py_opt                               :     0.000001s :  0.00%
#     auto_monad_reorder                   :     0.000035s :  0.02%
#     eliminate_forward_cnode              :     0.000002s :  0.00%
#     eliminate_ad_related_special_op_node :     0.000236s :  0.15%
#     validate                             :     0.000033s :  0.02%
#     distribtued_split                    :     0.000001s :  0.00%
#     task_emit                            :     0.008047s :  5.16%
#     execute                              :     0.000006s :  0.00%
#
# Time group info:
# ------[substitution.]   0.067507   630
#  0.13% :     0.000089s :     23: substitution.arithmetic_simplify
#  0.02% :     0.000014s :      8: substitution.arithmetic_simplify2
#  0.00% :     0.000002s :      2: substitution.depend_value_elim
# 98.79% :     0.066690s :    222: substitution.getattr_resolve
#  0.01% :     0.000007s :     13: substitution.graph_param_transform
#  0.72% :     0.000486s :     59: substitution.inline
#  0.17% :     0.000113s :    259: substitution.meta_fg_var_prepare
#  0.02% :     0.000011s :      2: substitution.minmaximum_grad
#  0.02% :     0.000015s :      2: substitution.reduce_eliminate
#  0.00% :     0.000002s :      1: substitution.replace_applicator
#  0.00% :     0.000002s :      2: substitution.replace_old_param
#  0.04% :     0.000024s :     17: substitution.switch_simplify
#  0.02% :     0.000011s :      2: substitution.tuple_list_convert_item_index_to_positive
#  0.01% :     0.000005s :      2: substitution.tuple_list_get_item_const_eliminator
#  0.01% :     0.000005s :      2: substitution.tuple_list_get_item_depend_reorder
#  0.04% :     0.000027s :     12: substitution.tuple_list_get_item_eliminator
#  0.01% :     0.000004s :      2: substitution.tuple_list_get_set_item_eliminator
# ------[renormalize.]   0.001463     2
# 63.34% :     0.000926s :      1: renormalize.infer
# 36.66% :     0.000536s :      1: renormalize.specialize
# ------[replace.]   0.002254   266
#  0.45% :     0.000010s :      2: replace.depend_value_elim
# 80.06% :     0.001805s :    178: replace.getattr_resolve
# 11.19% :     0.000252s :     59: replace.inline
#  5.46% :     0.000123s :     17: replace.switch_simplify
#  2.85% :     0.000064s :     10: replace.tuple_list_get_item_eliminator
# ------[match.]   0.067148   266
#  0.00% :     0.000002s :      2: match.depend_value_elim
# 99.21% :     0.066617s :    178: match.getattr_resolve
#  0.72% :     0.000486s :     59: match.inline
#  0.04% :     0.000024s :     17: match.switch_simplify
#  0.03% :     0.000020s :     10: match.tuple_list_get_item_eliminator
# ------[func_graph_cloner_run.]   0.009103    98
# 84.37% :     0.007681s :     36: func_graph_cloner_run.FuncGraphClonerGraph
#  0.13% :     0.000012s :      1: func_graph_cloner_run.FuncGraphClonerNode
# 15.50% :     0.001411s :     61: func_graph_cloner_run.FuncGraphSpecializer
# ------[meta_graph.]   0.000000     0
# ------[manager.]   0.000000     0
# ------[pynative]   0.000000     0
# ------[others.]   0.073237   132
#  0.73% :     0.000533s :     79: opt.transform.opt_a
#  0.24% :     0.000178s :     28: opt.transform.opt_b
# 95.23% :     0.069742s :      2: opt.transform.opt_resolve
#  0.01% :     0.000009s :      1: opt.transforms.ad_related_special_op_eliminate
#  0.52% :     0.000384s :      1: opt.transforms.inference_prepare
#  3.19% :     0.002333s :     18: opt.transforms.opt_a
#  0.02% :     0.000017s :      1: opt.transforms.opt_after_cconv
#  0.01% :     0.000006s :      1: opt.transforms.opt_b
#  0.05% :     0.000034s :      1: opt.transforms.opt_trans_graph

# %% [markdown]
# ## 动力学积分器
#
# 如果不对系统施加任何的限制，任由系统去演化的话，就只需要配置integrator积分器，常见的算法有LeapFrog与VelocityVerlet，在MindSponge的control中都是支持的。通过前面配置的各项势能项，利用MindSpore框架的自动微分，就可以计算出当前受力以及下一步的位移，进而实现分子系统的演化。
#
# 如果需要对系统施加以一定的控制，比如控制系统的温度，或者是控制系统的压强，在MindSponge的control中可以调用BerendsenThermostat、Barostat等算法，来跑一个NVT的系统，避免系统演化中可能出现的温度震荡现象。
#
# 后续在MindSponge的新版本中，还会对LINCS、SETTLE等键长约束算法进行支持，可以在动力学演化的过程中确保不会出现不合理的键长拉伸，最大程度上的保障分子系统键连关系的合理性。

# %%
opt = DynamicUpdater(system,
                     integrator=LeapFrog(system),
                     thermostat=BerendsenThermostat(system, 300),
                     time_step=1e-3,
                     velocity=velocity)

# %%
md = Sponge(system, potential, opt)
# Out:
# TotalTime = 0.339354, [19]
# [parse]: 0.00587304
# [symbol_resolve]: 0.057146, [1]
#     [Cycle 1]: 0.056314, [1]
#         [resolve]: 0.0563009
# [combine_like_graphs]: 1.44728e-06
# [inference_opt_prepare]: 0.000434842
# [abstract_specialize]: 0.241059
# [auto_monad]: 0.000615519
# [inline]: 2.15881e-06
# [py_pre_ad]: 1.62609e-06
# [pynative_shard]: 1.58511e-06
# [pipeline_split]: 5.76861e-06
# [optimize]: 0.025328, [15]
#     [simplify_data_structures]: 0.000273107
#     [opt_a]: 0.024218, [2]
#         [Cycle 1]: 0.0232167, [25]
#             [expand_dump_flag]: 1.09021e-05
#             [switch_simplify]: 0.000576558
#             [a_1]: 0.00530642
#             [recompute_prepare]: 2.53115e-05
#             [updatestate_depend_eliminate]: 1.73561e-05
#             [updatestate_assign_eliminate]: 1.51228e-05
#             [updatestate_loads_eliminate]: 1.53296e-05
#             [parameter_eliminate]: 2.25008e-06
#             [a_2]: 0.000652859
#             [accelerated_algorithm]: 1.63987e-05
#             [auto_parallel]: 3.33972e-06
#             [parallel]: 4.12017e-06
#             [allreduce_fusion]: 1.13212e-05
#             [virtual_dataset]: 9.50135e-06
#             [virtual_output]: 9.49576e-06
#             [shard]: 1.05146e-05
#             [meta_fg_expand]: 1.35992e-05
#             [after_resolve]: 6.99423e-06
#             [a_after_grad]: 1.10753e-05
#             [renormalize]: 0.0161383
#             [real_op_eliminate]: 1.52774e-05
#             [auto_monad_grad]: 3.20375e-06
#             [auto_monad_eliminator]: 2.41268e-05
#             [cse]: 0.000141632
#             [a_3]: 0.000109272
#         [Cycle 2]: 0.000607712, [25]
#             [expand_dump_flag]: 1.54041e-06
#             [switch_simplify]: 9.59076e-06
#             [a_1]: 0.000128282
#             [recompute_prepare]: 7.13393e-06
#             [updatestate_depend_eliminate]: 8.33161e-06
#             [updatestate_assign_eliminate]: 6.80797e-06
#             [updatestate_loads_eliminate]: 6.83032e-06
#             [parameter_eliminate]: 1.43982e-06
#             [a_2]: 0.000158478
#             [accelerated_algorithm]: 1.13621e-05
#             [auto_parallel]: 4.58024e-06
#             [parallel]: 2.61143e-06
#             [allreduce_fusion]: 5.07198e-06
#             [virtual_dataset]: 9.3244e-06
#             [virtual_output]: 9.03197e-06
#             [shard]: 8.62777e-06
#             [meta_fg_expand]: 1.36402e-05
#             [after_resolve]: 6.96816e-06
#             [a_after_grad]: 1.07531e-05
#             [renormalize]: 1.60187e-07
#             [real_op_eliminate]: 8.95187e-06
#             [auto_monad_grad]: 8.43778e-07
#             [auto_monad_eliminator]: 2.01426e-05
#             [cse]: 4.15817e-05
#             [a_3]: 9.21674e-05
#     [clean_after_opta]: 1.3411e-05
#     [opt_b]: 0.000341915, [1]
#         [Cycle 1]: 0.000338186, [7]
#             [b_1]: 0.000252942
#             [b_2]: 2.06176e-05
#             [updatestate_depend_eliminate]: 7.18795e-06
#             [updatestate_assign_eliminate]: 6.5919e-06
#             [updatestate_loads_eliminate]: 6.52485e-06
#             [renormalize]: 8.47504e-07
#             [cse]: 3.28012e-05
#     [cconv]: 1.7643e-05
#     [opt_after_cconv]: 8.38842e-05, [1]
#         [Cycle 1]: 8.10567e-05, [6]
#             [c_1]: 2.21841e-05
#             [updatestate_depend_eliminate]: 6.71484e-06
#             [updatestate_assign_eliminate]: 6.44848e-06
#             [updatestate_loads_eliminate]: 6.46338e-06
#             [cse]: 3.11993e-05
#             [renormalize]: 3.25963e-07
#     [remove_dup_value]: 0.000159355
#     [tuple_transform]: 4.5374e-05, [1]
#         [Cycle 1]: 4.25484e-05, [2]
#             [d_1]: 3.96967e-05
#             [renormalize]: 2.79397e-07
#     [add_cache_embedding]: 1.38767e-05
#     [add_recomputation]: 8.16472e-05
#     [cse_after_recomputation]: 3.62135e-05, [1]
#         [Cycle 1]: 3.27118e-05, [1]
#             [cse]: 3.08286e-05
#     [environ_conv]: 1.45361e-05
#     [slice_recompute_activation]: 1.60746e-06
#     [comm_op_add_attrs]: 6.48201e-07
#     [add_comm_op_reuse_tag]: 6.6869e-07
# [py_opt]: 1.87568e-06
# [auto_monad_reorder]: 3.39486e-05
# [eliminate_forward_cnode]: 5.12227e-07
# [eliminate_ad_related_special_op_node]: 0.000349518
# [validate]: 5.65443e-05
# [distribtued_split]: 8.64267e-07
# [task_emit]: 0.00832623
# [execute]: 4.17791e-06
# Sums
#     parse                                :     0.005873s :  1.74%
#     symbol_resolve.resolve               :     0.056301s : 16.66%
#     combine_like_graphs                  :     0.000001s :  0.00%
#     inference_opt_prepare                :     0.000435s :  0.13%
#     abstract_specialize                  :     0.241059s : 71.35%
#     auto_monad                           :     0.000616s :  0.18%
#     inline                               :     0.000002s :  0.00%
#     py_pre_ad                            :     0.000002s :  0.00%
#     pynative_shard                       :     0.000002s :  0.00%
#     pipeline_split                       :     0.000006s :  0.00%
#     optimize.simplify_data_structures    :     0.000273s :  0.08%
#     optimize.opt_a.expand_dump_flag      :     0.000012s :  0.00%
#     optimize.opt_a.switch_simplify       :     0.000586s :  0.17%
#     optimize.opt_a.a_1                   :     0.005435s :  1.61%
#     optimize.opt_a.recompute_prepare     :     0.000032s :  0.01%
#     optimize.opt_a.updatestate_depend_eliminate :     0.000026s :  0.01%
#     optimize.opt_a.updatestate_assign_eliminate :     0.000022s :  0.01%
#     optimize.opt_a.updatestate_loads_eliminate :     0.000022s :  0.01%
#     optimize.opt_a.parameter_eliminate   :     0.000004s :  0.00%
#     optimize.opt_a.a_2                   :     0.000811s :  0.24%
#     optimize.opt_a.accelerated_algorithm :     0.000028s :  0.01%
#     optimize.opt_a.auto_parallel         :     0.000008s :  0.00%
#     optimize.opt_a.parallel              :     0.000007s :  0.00%
#     optimize.opt_a.allreduce_fusion      :     0.000016s :  0.00%
#     optimize.opt_a.virtual_dataset       :     0.000019s :  0.01%
#     optimize.opt_a.virtual_output        :     0.000019s :  0.01%
#     optimize.opt_a.shard                 :     0.000019s :  0.01%
#     optimize.opt_a.meta_fg_expand        :     0.000027s :  0.01%
#     optimize.opt_a.after_resolve         :     0.000014s :  0.00%
#     optimize.opt_a.a_after_grad          :     0.000022s :  0.01%
#     optimize.opt_a.renormalize           :     0.016138s :  4.78%
#     optimize.opt_a.real_op_eliminate     :     0.000024s :  0.01%
#     optimize.opt_a.auto_monad_grad       :     0.000004s :  0.00%
#     optimize.opt_a.auto_monad_eliminator :     0.000044s :  0.01%
#     optimize.opt_a.cse                   :     0.000183s :  0.05%
#     optimize.opt_a.a_3                   :     0.000201s :  0.06%
#     optimize.clean_after_opta            :     0.000013s :  0.00%
#     optimize.opt_b.b_1                   :     0.000253s :  0.07%
#     optimize.opt_b.b_2                   :     0.000021s :  0.01%
#     optimize.opt_b.updatestate_depend_eliminate :     0.000007s :  0.00%
#     optimize.opt_b.updatestate_assign_eliminate :     0.000007s :  0.00%
#     optimize.opt_b.updatestate_loads_eliminate :     0.000007s :  0.00%
#     optimize.opt_b.renormalize           :     0.000001s :  0.00%
#     optimize.opt_b.cse                   :     0.000033s :  0.01%
#     optimize.cconv                       :     0.000018s :  0.01%
#     optimize.opt_after_cconv.c_1         :     0.000022s :  0.01%
#     optimize.opt_after_cconv.updatestate_depend_eliminate :     0.000007s :  0.00%
#     optimize.opt_after_cconv.updatestate_assign_eliminate :     0.000006s :  0.00%
#     optimize.opt_after_cconv.updatestate_loads_eliminate :     0.000006s :  0.00%
#     optimize.opt_after_cconv.cse         :     0.000031s :  0.01%
#     optimize.opt_after_cconv.renormalize :     0.000000s :  0.00%
#     optimize.remove_dup_value            :     0.000159s :  0.05%
#     optimize.tuple_transform.d_1         :     0.000040s :  0.01%
#     optimize.tuple_transform.renormalize :     0.000000s :  0.00%
#     optimize.add_cache_embedding         :     0.000014s :  0.00%
#     optimize.add_recomputation           :     0.000082s :  0.02%
#     optimize.cse_after_recomputation.cse :     0.000031s :  0.01%
#     optimize.environ_conv                :     0.000015s :  0.00%
#     optimize.slice_recompute_activation  :     0.000002s :  0.00%
#     optimize.comm_op_add_attrs           :     0.000001s :  0.00%
#     optimize.add_comm_op_reuse_tag       :     0.000001s :  0.00%
#     py_opt                               :     0.000002s :  0.00%
#     auto_monad_reorder                   :     0.000034s :  0.01%
#     eliminate_forward_cnode              :     0.000001s :  0.00%
#     eliminate_ad_related_special_op_node :     0.000350s :  0.10%
#     validate                             :     0.000057s :  0.02%
#     distribtued_split                    :     0.000001s :  0.00%
#     task_emit                            :     0.008326s :  2.46%
#     execute                              :     0.000004s :  0.00%
#
# Time group info:
# ------[substitution.]   0.055370  1042
#  0.45% :     0.000248s :     24: substitution.cast_eliminate
#  0.02% :     0.000011s :     19: substitution.depend_value_elim
# 95.97% :     0.053138s :    209: substitution.getattr_resolve
#  0.02% :     0.000009s :     13: substitution.graph_param_transform
#  2.11% :     0.001169s :    137: substitution.inline
#  0.01% :     0.000006s :      2: substitution.less_batch_normalization
#  0.22% :     0.000120s :    255: substitution.meta_fg_var_prepare
#  0.07% :     0.000037s :     46: substitution.minmaximum_grad
#  0.03% :     0.000015s :      3: substitution.reshape_eliminate
#  0.07% :     0.000036s :     37: substitution.switch_simplify
#  0.04% :     0.000024s :     11: substitution.tile_eliminate
#  0.38% :     0.000210s :     46: substitution.tuple_list_convert_item_index_to_positive
#  0.10% :     0.000055s :     55: substitution.tuple_list_get_item_const_eliminator
#  0.18% :     0.000099s :     55: substitution.tuple_list_get_item_depend_reorder
#  0.21% :     0.000115s :     73: substitution.tuple_list_get_item_eliminator
#  0.13% :     0.000071s :     55: substitution.tuple_list_get_set_item_eliminator
#  0.01% :     0.000006s :      2: substitution.value_based_eliminate
# ------[renormalize.]   0.016133     2
# 55.71% :     0.008988s :      1: renormalize.infer
# 44.29% :     0.007145s :      1: renormalize.specialize
# ------[replace.]   0.003036   396
#  0.64% :     0.000020s :      2: replace.cast_eliminate
#  2.72% :     0.000083s :     19: replace.depend_value_elim
# 59.90% :     0.001818s :    170: replace.getattr_resolve
# 20.87% :     0.000633s :    137: replace.inline
#  0.42% :     0.000013s :      3: replace.reshape_eliminate
#  8.83% :     0.000268s :     37: replace.switch_simplify
#  0.16% :     0.000005s :      1: replace.tile_eliminate
#  2.97% :     0.000090s :      9: replace.tuple_list_get_item_depend_reorder
#  3.48% :     0.000106s :     18: replace.tuple_list_get_item_eliminator
# ------[match.]   0.054548   396
#  0.30% :     0.000165s :      2: match.cast_eliminate
#  0.02% :     0.000011s :     19: match.depend_value_elim
# 97.31% :     0.053078s :    170: match.getattr_resolve
#  2.14% :     0.001169s :    137: match.inline
#  0.03% :     0.000015s :      3: match.reshape_eliminate
#  0.07% :     0.000036s :     37: match.switch_simplify
#  0.01% :     0.000004s :      1: match.tile_eliminate
#  0.07% :     0.000039s :      9: match.tuple_list_get_item_depend_reorder
#  0.06% :     0.000030s :     18: match.tuple_list_get_item_eliminator
# ------[func_graph_cloner_run.]   0.032406   440
# 70.89% :     0.022974s :    301: func_graph_cloner_run.FuncGraphClonerGraph
#  0.19% :     0.000060s :      6: func_graph_cloner_run.FuncGraphClonerNode
# 28.92% :     0.009372s :    133: func_graph_cloner_run.FuncGraphSpecializer
# ------[meta_graph.]   0.000000     0
# ------[manager.]   0.000000     0
# ------[pynative]   0.000000     0
# ------[others.]   0.064189   132
#  1.53% :     0.000981s :     79: opt.transform.opt_a
#  0.38% :     0.000242s :     28: opt.transform.opt_b
# 87.70% :     0.056296s :      2: opt.transform.opt_resolve
#  0.02% :     0.000011s :      1: opt.transforms.ad_related_special_op_eliminate
#  0.66% :     0.000422s :      1: opt.transforms.inference_prepare
#  9.60% :     0.006159s :     18: opt.transforms.opt_a
#  0.03% :     0.000021s :      1: opt.transforms.opt_after_cconv
#  0.03% :     0.000019s :      1: opt.transforms.opt_b
#  0.06% :     0.000038s :      1: opt.transforms.opt_trans_graph

# %% [markdown]
# ## 信息回调
#
# 基于MindSpore的信息回调系统CallBack，我们可以创建一些符合自己需求的信息回调机制，比如使用RunInfo在屏幕上对系统能量进行输出，或者是通过WriteH5MD将轨迹输出到hdf5/h5md文件中。
#
# 关于h5md格式的轨迹输出，可以使用改进版的VMD-h5mdplugin进行可视化，相关安装和说明链接为：https://gitee.com/helloyesterday/VMD-h5mdplugin

# %%
run_info = RunInfo(10)
cb_h5md = WriteH5MD(system, 'tutorial_b01.h5md', save_freq=10, write_velocity=True, write_force=True)

# %%
md.run(1000, callbacks=[run_info, cb_h5md])
# Out:
# TotalTime = 0.0163505, [19]
# [parse]: 0.00723182
# [symbol_resolve]: 0.00106402, [1]
#     [Cycle 1]: 0.001034, [1]
#         [resolve]: 0.00102836
# [combine_like_graphs]: 6.94767e-07
# [inference_opt_prepare]: 2.78e-05
# [abstract_specialize]: 0.000662819
# [auto_monad]: 0.000122383
# [inline]: 1.62236e-06
# [py_pre_ad]: 1.30571e-06
# [pynative_shard]: 1.16043e-06
# [pipeline_split]: 2.00421e-06
# [optimize]: 0.00188927, [15]
#     [simplify_data_structures]: 8.42474e-06
#     [opt_a]: 0.00152243, [2]
#         [Cycle 1]: 0.000888854, [25]
#             [expand_dump_flag]: 1.63168e-06
#             [switch_simplify]: 9.95584e-06
#             [a_1]: 0.0001512
#             [recompute_prepare]: 3.65078e-06
#             [updatestate_depend_eliminate]: 2.4857e-05
#             [updatestate_assign_eliminate]: 4.692e-06
#             [updatestate_loads_eliminate]: 4.00655e-06
#             [parameter_eliminate]: 1.7751e-06
#             [a_2]: 6.41923e-05
#             [accelerated_algorithm]: 6.13928e-06
#             [auto_parallel]: 1.89804e-06
#             [parallel]: 2.80887e-06
#             [allreduce_fusion]: 3.43658e-06
#             [virtual_dataset]: 3.65078e-06
#             [virtual_output]: 3.4757e-06
#             [shard]: 4.80935e-06
#             [meta_fg_expand]: 5.70528e-06
#             [after_resolve]: 5.18374e-06
#             [a_after_grad]: 4.37349e-06
#             [renormalize]: 0.000452584
#             [real_op_eliminate]: 5.15021e-06
#             [auto_monad_grad]: 2.24076e-06
#             [auto_monad_eliminator]: 2.10684e-05
#             [cse]: 2.07014e-05
#             [a_3]: 3.60515e-05
#         [Cycle 2]: 0.000260305, [25]
#             [expand_dump_flag]: 7.46921e-07
#             [switch_simplify]: 3.64147e-06
#             [a_1]: 4.88758e-05
#             [recompute_prepare]: 2.73623e-06
#             [updatestate_depend_eliminate]: 3.74764e-06
#             [updatestate_assign_eliminate]: 3.2708e-06
#             [updatestate_loads_eliminate]: 3.60422e-06
#             [parameter_eliminate]: 9.07108e-07
#             [a_2]: 6.14282e-05
#             [accelerated_algorithm]: 4.73298e-06
#             [auto_parallel]: 1.99676e-06
#             [parallel]: 1.61491e-06
#             [allreduce_fusion]: 2.36556e-06
#             [virtual_dataset]: 3.45893e-06
#             [virtual_output]: 3.37139e-06
#             [shard]: 3.69549e-06
#             [meta_fg_expand]: 5.39422e-06
#             [after_resolve]: 4.12017e-06
#             [a_after_grad]: 4.19281e-06
#             [renormalize]: 1.76951e-07
#             [real_op_eliminate]: 3.4757e-06
#             [auto_monad_grad]: 6.7614e-07
#             [auto_monad_eliminator]: 1.21798e-05
#             [cse]: 1.43833e-05
#             [a_3]: 3.39877e-05
#     [clean_after_opta]: 4.91366e-06
#     [opt_b]: 0.000142647, [1]
#         [Cycle 1]: 0.000139793, [7]
#             [b_1]: 0.000102447
#             [b_2]: 4.23193e-06
#             [updatestate_depend_eliminate]: 3.41423e-06
#             [updatestate_assign_eliminate]: 3.10503e-06
#             [updatestate_loads_eliminate]: 3.36766e-06
#             [renormalize]: 3.09199e-07
#             [cse]: 1.3575e-05
#     [cconv]: 1.19917e-05
#     [opt_after_cconv]: 4.69275e-05, [1]
#         [Cycle 1]: 4.42602e-05, [6]
#             [c_1]: 1.3534e-05
#             [updatestate_depend_eliminate]: 3.14787e-06
#             [updatestate_assign_eliminate]: 3.03052e-06
#             [updatestate_loads_eliminate]: 3.45521e-06
#             [cse]: 1.28001e-05
#             [renormalize]: 2.73809e-07
#     [remove_dup_value]: 3.20449e-05
#     [tuple_transform]: 2.41175e-05, [1]
#         [Cycle 1]: 2.15545e-05, [2]
#             [d_1]: 1.88239e-05
#             [renormalize]: 2.79397e-07
#     [add_cache_embedding]: 8.80659e-06
#     [add_recomputation]: 3.76422e-05
#     [cse_after_recomputation]: 1.82893e-05, [1]
#         [Cycle 1]: 1.55382e-05, [1]
#             [cse]: 1.40369e-05
#     [environ_conv]: 7.15256e-06
#     [slice_recompute_activation]: 1.16974e-06
#     [comm_op_add_attrs]: 4.84288e-07
#     [add_comm_op_reuse_tag]: 6.03497e-07
# [py_opt]: 1.07102e-06
# [auto_monad_reorder]: 2.0422e-05
# [eliminate_forward_cnode]: 4.17233e-07
# [eliminate_ad_related_special_op_node]: 0.0002227
# [validate]: 1.75256e-05
# [distribtued_split]: 6.38887e-07
# [task_emit]: 0.00499317
# [execute]: 3.60794e-06
# Sums
#     parse                                :     0.007232s : 45.98%
#     symbol_resolve.resolve               :     0.001028s :  6.54%
#     combine_like_graphs                  :     0.000001s :  0.00%
#     inference_opt_prepare                :     0.000028s :  0.18%
#     abstract_specialize                  :     0.000663s :  4.21%
#     auto_monad                           :     0.000122s :  0.78%
#     inline                               :     0.000002s :  0.01%
#     py_pre_ad                            :     0.000001s :  0.01%
#     pynative_shard                       :     0.000001s :  0.01%
#     pipeline_split                       :     0.000002s :  0.01%
#     optimize.simplify_data_structures    :     0.000008s :  0.05%
#     optimize.opt_a.expand_dump_flag      :     0.000002s :  0.02%
#     optimize.opt_a.switch_simplify       :     0.000014s :  0.09%
#     optimize.opt_a.a_1                   :     0.000200s :  1.27%
#     optimize.opt_a.recompute_prepare     :     0.000006s :  0.04%
#     optimize.opt_a.updatestate_depend_eliminate :     0.000029s :  0.18%
#     optimize.opt_a.updatestate_assign_eliminate :     0.000008s :  0.05%
#     optimize.opt_a.updatestate_loads_eliminate :     0.000008s :  0.05%
#     optimize.opt_a.parameter_eliminate   :     0.000003s :  0.02%
#     optimize.opt_a.a_2                   :     0.000126s :  0.80%
#     optimize.opt_a.accelerated_algorithm :     0.000011s :  0.07%
#     optimize.opt_a.auto_parallel         :     0.000004s :  0.02%
#     optimize.opt_a.parallel              :     0.000004s :  0.03%
#     optimize.opt_a.allreduce_fusion      :     0.000006s :  0.04%
#     optimize.opt_a.virtual_dataset       :     0.000007s :  0.05%
#     optimize.opt_a.virtual_output        :     0.000007s :  0.04%
#     optimize.opt_a.shard                 :     0.000009s :  0.05%
#     optimize.opt_a.meta_fg_expand        :     0.000011s :  0.07%
#     optimize.opt_a.after_resolve         :     0.000009s :  0.06%
#     optimize.opt_a.a_after_grad          :     0.000009s :  0.05%
#     optimize.opt_a.renormalize           :     0.000453s :  2.88%
#     optimize.opt_a.real_op_eliminate     :     0.000009s :  0.05%
#     optimize.opt_a.auto_monad_grad       :     0.000003s :  0.02%
#     optimize.opt_a.auto_monad_eliminator :     0.000033s :  0.21%
#     optimize.opt_a.cse                   :     0.000035s :  0.22%
#     optimize.opt_a.a_3                   :     0.000070s :  0.45%
#     optimize.clean_after_opta            :     0.000005s :  0.03%
#     optimize.opt_b.b_1                   :     0.000102s :  0.65%
#     optimize.opt_b.b_2                   :     0.000004s :  0.03%
#     optimize.opt_b.updatestate_depend_eliminate :     0.000003s :  0.02%
#     optimize.opt_b.updatestate_assign_eliminate :     0.000003s :  0.02%
#     optimize.opt_b.updatestate_loads_eliminate :     0.000003s :  0.02%
#     optimize.opt_b.renormalize           :     0.000000s :  0.00%
#     optimize.opt_b.cse                   :     0.000014s :  0.09%
#     optimize.cconv                       :     0.000012s :  0.08%
#     optimize.opt_after_cconv.c_1         :     0.000014s :  0.09%
#     optimize.opt_after_cconv.updatestate_depend_eliminate :     0.000003s :  0.02%
#     optimize.opt_after_cconv.updatestate_assign_eliminate :     0.000003s :  0.02%
#     optimize.opt_after_cconv.updatestate_loads_eliminate :     0.000003s :  0.02%
#     optimize.opt_after_cconv.cse         :     0.000013s :  0.08%
#     optimize.opt_after_cconv.renormalize :     0.000000s :  0.00%
#     optimize.remove_dup_value            :     0.000032s :  0.20%
#     optimize.tuple_transform.d_1         :     0.000019s :  0.12%
#     optimize.tuple_transform.renormalize :     0.000000s :  0.00%
#     optimize.add_cache_embedding         :     0.000009s :  0.06%
#     optimize.add_recomputation           :     0.000038s :  0.24%
#     optimize.cse_after_recomputation.cse :     0.000014s :  0.09%
#     optimize.environ_conv                :     0.000007s :  0.05%
#     optimize.slice_recompute_activation  :     0.000001s :  0.01%
#     optimize.comm_op_add_attrs           :     0.000000s :  0.00%
#     optimize.add_comm_op_reuse_tag       :     0.000001s :  0.00%
#     py_opt                               :     0.000001s :  0.01%
#     auto_monad_reorder                   :     0.000020s :  0.13%
#     eliminate_forward_cnode              :     0.000000s :  0.00%
#     eliminate_ad_related_special_op_node :     0.000223s :  1.42%
#     validate                             :     0.000018s :  0.11%
#     distribtued_split                    :     0.000001s :  0.00%
#     task_emit                            :     0.004993s : 31.75%
#     execute                              :     0.000004s :  0.02%
#
# Time group info:
# ------[substitution.]   0.000977    58
#  0.33% :     0.000003s :      2: substitution.depend_value_elim
# 92.08% :     0.000900s :      9: substitution.getattr_resolve
#  0.45% :     0.000004s :      6: substitution.graph_param_transform
#  3.41% :     0.000033s :      2: substitution.inline
#  0.19% :     0.000002s :      2: substitution.less_batch_normalization
#  0.22% :     0.000002s :      6: substitution.load_eliminater
#  0.72% :     0.000007s :     11: substitution.meta_fg_var_prepare
#  0.16% :     0.000002s :      2: substitution.replace_old_param
#  1.11% :     0.000011s :      8: substitution.updatestate_pure_node_eliminater
#  1.35% :     0.000013s :     10: substitution.updatestate_useless_node_eliminater
# ------[renormalize.]   0.000450     2
# 53.02% :     0.000238s :      1: renormalize.infer
# 46.98% :     0.000211s :      1: renormalize.specialize
# ------[replace.]   0.000084     9
# 86.29% :     0.000072s :      7: replace.getattr_resolve
# 13.71% :     0.000011s :      2: replace.inline
# ------[match.]   0.000930     9
# 96.42% :     0.000897s :      7: match.getattr_resolve
#  3.58% :     0.000033s :      2: match.inline
# ------[func_graph_cloner_run.]   0.000223     5
#  3.87% :     0.000009s :      1: func_graph_cloner_run.FuncGraphClonerGraph
# 96.13% :     0.000214s :      4: func_graph_cloner_run.FuncGraphSpecializer
# ------[meta_graph.]   0.000000     0
# ------[manager.]   0.000000     0
# ------[pynative]   0.000000     0
# ------[others.]   0.001607   113
# 10.85% :     0.000174s :     60: opt.transform.opt_a
#  5.78% :     0.000093s :     28: opt.transform.opt_b
# 63.79% :     0.001025s :      2: opt.transform.opt_resolve
#  0.29% :     0.000005s :      1: opt.transforms.ad_related_special_op_eliminate
#  1.21% :     0.000019s :      1: opt.transforms.inference_prepare
# 16.03% :     0.000258s :     18: opt.transforms.opt_a
#  0.77% :     0.000012s :      1: opt.transforms.opt_after_cconv
#  0.19% :     0.000003s :      1: opt.transforms.opt_b
#  1.10% :     0.000018s :      1: opt.transforms.opt_trans_graph
# TotalTime = 0.308485, [19]
# [parse]: 0.00398725
# [symbol_resolve]: 0.0476455, [1]
#     [Cycle 1]: 0.0471552, [1]
#         [resolve]: 0.0471463
# [combine_like_graphs]: 8.51229e-07
# [inference_opt_prepare]: 0.000430869
# [abstract_specialize]: 0.217133
# [auto_monad]: 0.000703394
# [inline]: 1.92225e-06
# [py_pre_ad]: 9.00961e-06
# [pynative_shard]: 1.87941e-06
# [pipeline_split]: 9.38959e-06
# [optimize]: 0.0276769, [15]
#     [simplify_data_structures]: 0.000288436
#     [opt_a]: 0.0263254, [2]
#         [Cycle 1]: 0.0251125, [25]
#             [expand_dump_flag]: 1.04588e-05
#             [switch_simplify]: 0.000586547
#             [a_1]: 0.00573784
#             [recompute_prepare]: 2.04202e-05
#             [updatestate_depend_eliminate]: 4.8086e-05
#             [updatestate_assign_eliminate]: 1.86618e-05
#             [updatestate_loads_eliminate]: 1.71214e-05
#             [parameter_eliminate]: 1.95205e-06
#             [a_2]: 0.000728277
#             [accelerated_algorithm]: 1.11889e-05
#             [auto_parallel]: 3.61353e-06
#             [parallel]: 3.59118e-06
#             [allreduce_fusion]: 1.2584e-05
#             [virtual_dataset]: 1.11554e-05
#             [virtual_output]: 1.11833e-05
#             [shard]: 1.24481e-05
#             [meta_fg_expand]: 1.611e-05
#             [after_resolve]: 1.08369e-05
#             [a_after_grad]: 1.28448e-05
#             [renormalize]: 0.0173059
#             [real_op_eliminate]: 1.97552e-05
#             [auto_monad_grad]: 5.05522e-06
#             [auto_monad_eliminator]: 3.26429e-05
#             [cse]: 0.000294605
#             [a_3]: 0.000117654
#         [Cycle 2]: 0.000768943, [25]
#             [expand_dump_flag]: 2.27988e-06
#             [switch_simplify]: 1.13249e-05
#             [a_1]: 0.000169132
#             [recompute_prepare]: 8.34279e-06
#             [updatestate_depend_eliminate]: 1.12168e-05
#             [updatestate_assign_eliminate]: 9.55537e-06
#             [updatestate_loads_eliminate]: 8.73767e-06
#             [parameter_eliminate]: 1.70432e-06
#             [a_2]: 0.000198845
#             [accelerated_algorithm]: 1.09747e-05
#             [auto_parallel]: 8.23103e-06
#             [parallel]: 3.2708e-06
#             [allreduce_fusion]: 6.97933e-06
#             [virtual_dataset]: 1.12373e-05
#             [virtual_output]: 1.09877e-05
#             [shard]: 1.14758e-05
#             [meta_fg_expand]: 1.65701e-05
#             [after_resolve]: 1.16806e-05
#             [a_after_grad]: 1.3195e-05
#             [renormalize]: 1.80677e-07
#             [real_op_eliminate]: 1.06841e-05
#             [auto_monad_grad]: 9.81614e-07
#             [auto_monad_eliminator]: 2.61962e-05
#             [cse]: 4.9796e-05
#             [a_3]: 0.000119649
#     [clean_after_opta]: 1.53314e-05
#     [opt_b]: 0.000400167, [1]
#         [Cycle 1]: 0.000396224, [7]
#             [b_1]: 0.00030796
#             [b_2]: 1.17403e-05
#             [updatestate_depend_eliminate]: 8.70042e-06
#             [updatestate_assign_eliminate]: 8.89599e-06
#             [updatestate_loads_eliminate]: 8.25897e-06
#             [renormalize]: 6.96629e-07
#             [cse]: 3.91118e-05
#     [cconv]: 2.01073e-05
#     [opt_after_cconv]: 0.000104574, [1]
#         [Cycle 1]: 0.000101225, [6]
#             [c_1]: 3.07616e-05
#             [updatestate_depend_eliminate]: 8.48249e-06
#             [updatestate_assign_eliminate]: 8.70414e-06
#             [updatestate_loads_eliminate]: 8.1379e-06
#             [cse]: 3.68953e-05
#             [renormalize]: 2.71946e-07
#     [remove_dup_value]: 0.000242746
#     [tuple_transform]: 5.36032e-05, [1]
#         [Cycle 1]: 5.07031e-05, [2]
#             [d_1]: 4.77061e-05
#             [renormalize]: 2.38419e-07
#     [add_cache_embedding]: 1.69408e-05
#     [add_recomputation]: 0.000114134
#     [cse_after_recomputation]: 4.52343e-05, [1]
#         [Cycle 1]: 4.2012e-05, [1]
#             [cse]: 4.00003e-05
#     [environ_conv]: 1.81478e-05
#     [slice_recompute_activation]: 1.72853e-06
#     [comm_op_add_attrs]: 7.28294e-07
#     [add_comm_op_reuse_tag]: 6.83591e-07
# [py_opt]: 1.96695e-06
# [auto_monad_reorder]: 4.11961e-05
# [eliminate_forward_cnode]: 5.23403e-07
# [eliminate_ad_related_special_op_node]: 0.000400459
# [validate]: 4.99431e-05
# [distribtued_split]: 9.44361e-07
# [task_emit]: 0.0102534
# [execute]: 4.41633e-06
# Sums
#     parse                                :     0.003987s :  1.30%
#     symbol_resolve.resolve               :     0.047146s : 15.34%
#     combine_like_graphs                  :     0.000001s :  0.00%
#     inference_opt_prepare                :     0.000431s :  0.14%
#     abstract_specialize                  :     0.217133s : 70.67%
#     auto_monad                           :     0.000703s :  0.23%
#     inline                               :     0.000002s :  0.00%
#     py_pre_ad                            :     0.000009s :  0.00%
#     pynative_shard                       :     0.000002s :  0.00%
#     pipeline_split                       :     0.000009s :  0.00%
#     optimize.simplify_data_structures    :     0.000288s :  0.09%
#     optimize.opt_a.expand_dump_flag      :     0.000013s :  0.00%
#     optimize.opt_a.switch_simplify       :     0.000598s :  0.19%
#     optimize.opt_a.a_1                   :     0.005907s :  1.92%
#     optimize.opt_a.recompute_prepare     :     0.000029s :  0.01%
#     optimize.opt_a.updatestate_depend_eliminate :     0.000059s :  0.02%
#     optimize.opt_a.updatestate_assign_eliminate :     0.000028s :  0.01%
#     optimize.opt_a.updatestate_loads_eliminate :     0.000026s :  0.01%
#     optimize.opt_a.parameter_eliminate   :     0.000004s :  0.00%
#     optimize.opt_a.a_2                   :     0.000927s :  0.30%
#     optimize.opt_a.accelerated_algorithm :     0.000022s :  0.01%
#     optimize.opt_a.auto_parallel         :     0.000012s :  0.00%
#     optimize.opt_a.parallel              :     0.000007s :  0.00%
#     optimize.opt_a.allreduce_fusion      :     0.000020s :  0.01%
#     optimize.opt_a.virtual_dataset       :     0.000022s :  0.01%
#     optimize.opt_a.virtual_output        :     0.000022s :  0.01%
#     optimize.opt_a.shard                 :     0.000024s :  0.01%
#     optimize.opt_a.meta_fg_expand        :     0.000033s :  0.01%
#     optimize.opt_a.after_resolve         :     0.000023s :  0.01%
#     optimize.opt_a.a_after_grad          :     0.000026s :  0.01%
#     optimize.opt_a.renormalize           :     0.017306s :  5.63%
#     optimize.opt_a.real_op_eliminate     :     0.000030s :  0.01%
#     optimize.opt_a.auto_monad_grad       :     0.000006s :  0.00%
#     optimize.opt_a.auto_monad_eliminator :     0.000059s :  0.02%
#     optimize.opt_a.cse                   :     0.000344s :  0.11%
#     optimize.opt_a.a_3                   :     0.000237s :  0.08%
#     optimize.clean_after_opta            :     0.000015s :  0.00%
#     optimize.opt_b.b_1                   :     0.000308s :  0.10%
#     optimize.opt_b.b_2                   :     0.000012s :  0.00%
#     optimize.opt_b.updatestate_depend_eliminate :     0.000009s :  0.00%
#     optimize.opt_b.updatestate_assign_eliminate :     0.000009s :  0.00%
#     optimize.opt_b.updatestate_loads_eliminate :     0.000008s :  0.00%
#     optimize.opt_b.renormalize           :     0.000001s :  0.00%
#     optimize.opt_b.cse                   :     0.000039s :  0.01%
#     optimize.cconv                       :     0.000020s :  0.01%
#     optimize.opt_after_cconv.c_1         :     0.000031s :  0.01%
#     optimize.opt_after_cconv.updatestate_depend_eliminate :     0.000008s :  0.00%
#     optimize.opt_after_cconv.updatestate_assign_eliminate :     0.000009s :  0.00%
#     optimize.opt_after_cconv.updatestate_loads_eliminate :     0.000008s :  0.00%
#     optimize.opt_after_cconv.cse         :     0.000037s :  0.01%
#     optimize.opt_after_cconv.renormalize :     0.000000s :  0.00%
#     optimize.remove_dup_value            :     0.000243s :  0.08%
#     optimize.tuple_transform.d_1         :     0.000048s :  0.02%
#     optimize.tuple_transform.renormalize :     0.000000s :  0.00%
#     optimize.add_cache_embedding         :     0.000017s :  0.01%
#     optimize.add_recomputation           :     0.000114s :  0.04%
#     optimize.cse_after_recomputation.cse :     0.000040s :  0.01%
#     optimize.environ_conv                :     0.000018s :  0.01%
#     optimize.slice_recompute_activation  :     0.000002s :  0.00%
#     optimize.comm_op_add_attrs           :     0.000001s :  0.00%
#     optimize.add_comm_op_reuse_tag       :     0.000001s :  0.00%
#     py_opt                               :     0.000002s :  0.00%
#     auto_monad_reorder                   :     0.000041s :  0.01%
#     eliminate_forward_cnode              :     0.000001s :  0.00%
#     eliminate_ad_related_special_op_node :     0.000400s :  0.13%
#     validate                             :     0.000050s :  0.02%
#     distribtued_split                    :     0.000001s :  0.00%
#     task_emit                            :     0.010253s :  3.34%
#     execute                              :     0.000004s :  0.00%
#
# Time group info:
# ------[substitution.]   0.046711  1138
#  0.59% :     0.000274s :     23: substitution.cast_eliminate
#  0.04% :     0.000019s :     25: substitution.depend_value_elim
# 94.32% :     0.044058s :    223: substitution.getattr_resolve
#  0.02% :     0.000011s :     17: substitution.graph_param_transform
#  2.84% :     0.001327s :    142: substitution.inline
#  0.26% :     0.000123s :    268: substitution.meta_fg_var_prepare
#  0.09% :     0.000040s :     50: substitution.minmaximum_grad
#  0.01% :     0.000003s :      2: substitution.replace_old_param
#  0.23% :     0.000109s :      3: substitution.reshape_eliminate
#  0.08% :     0.000036s :     38: substitution.switch_simplify
#  0.06% :     0.000027s :     11: substitution.tile_eliminate
#  0.60% :     0.000280s :     50: substitution.tuple_list_convert_item_index_to_positive
#  0.12% :     0.000058s :     59: substitution.tuple_list_get_item_const_eliminator
#  0.24% :     0.000110s :     59: substitution.tuple_list_get_item_depend_reorder
#  0.25% :     0.000116s :     76: substitution.tuple_list_get_item_eliminator
#  0.16% :     0.000077s :     59: substitution.tuple_list_get_set_item_eliminator
#  0.05% :     0.000024s :     14: substitution.updatestate_pure_node_eliminater
#  0.03% :     0.000014s :     17: substitution.updatestate_useless_node_eliminater
#  0.01% :     0.000006s :      2: substitution.value_based_eliminate
# ------[renormalize.]   0.017300     2
# 68.33% :     0.011821s :      1: renormalize.infer
# 31.67% :     0.005479s :      1: renormalize.specialize
# ------[replace.]   0.003126   413
#  0.58% :     0.000018s :      2: replace.cast_eliminate
#  2.56% :     0.000080s :     19: replace.depend_value_elim
# 60.39% :     0.001888s :    182: replace.getattr_resolve
# 20.64% :     0.000645s :    142: replace.inline
#  0.45% :     0.000014s :      3: replace.reshape_eliminate
#  8.63% :     0.000270s :     38: replace.switch_simplify
#  0.13% :     0.000004s :      1: replace.tile_eliminate
#  2.87% :     0.000090s :      9: replace.tuple_list_get_item_depend_reorder
#  3.74% :     0.000117s :     17: replace.tuple_list_get_item_eliminator
# ------[match.]   0.045744   413
#  0.43% :     0.000198s :      2: match.cast_eliminate
#  0.02% :     0.000010s :     19: match.depend_value_elim
# 96.18% :     0.043997s :    182: match.getattr_resolve
#  2.90% :     0.001327s :    142: match.inline
#  0.24% :     0.000109s :      3: match.reshape_eliminate
#  0.08% :     0.000036s :     38: match.switch_simplify
#  0.01% :     0.000004s :      1: match.tile_eliminate
#  0.08% :     0.000034s :      9: match.tuple_list_get_item_depend_reorder
#  0.06% :     0.000028s :     17: match.tuple_list_get_item_eliminator
# ------[func_graph_cloner_run.]   0.037557   447
# 78.01% :     0.029297s :    303: func_graph_cloner_run.FuncGraphClonerGraph
#  0.17% :     0.000065s :      6: func_graph_cloner_run.FuncGraphClonerNode
# 21.82% :     0.008195s :    138: func_graph_cloner_run.FuncGraphSpecializer
# ------[meta_graph.]   0.000000     0
# ------[manager.]   0.000000     0
# ------[pynative]   0.000000     0
# ------[others.]   0.055752   132
#  2.03% :     0.001133s :     79: opt.transform.opt_a
#  0.53% :     0.000297s :     28: opt.transform.opt_b
# 84.56% :     0.047143s :      2: opt.transform.opt_resolve
#  0.02% :     0.000013s :      1: opt.transforms.ad_related_special_op_eliminate
#  0.75% :     0.000419s :      1: opt.transforms.inference_prepare
# 11.95% :     0.006660s :     18: opt.transforms.opt_a
#  0.05% :     0.000029s :      1: opt.transforms.opt_after_cconv
#  0.02% :     0.000010s :      1: opt.transforms.opt_b
#  0.08% :     0.000046s :      1: opt.transforms.opt_trans_graph
# TotalTime = 1.54673, [19]
# [parse]: 0.00546663
# [symbol_resolve]: 0.309384, [1]
#     [Cycle 1]: 0.306292, [1]
#         [resolve]: 0.306278
# [combine_like_graphs]: 7.17118e-07
# [inference_opt_prepare]: 0.0023376
# [abstract_specialize]: 0.597489
# [auto_monad]: 0.00272803
# [inline]: 1.25729e-05
# [py_pre_ad]: 1.84402e-06
# [pynative_shard]: 1.51061e-06
# [pipeline_split]: 1.03004e-05
# [optimize]: 0.558389, [15]
#     [simplify_data_structures]: 0.00124547
#     [opt_a]: 0.549906, [4]
#         [Cycle 1]: 0.477438, [25]
#             [expand_dump_flag]: 2.77534e-05
#             [switch_simplify]: 0.00163234
#             [a_1]: 0.0210137
#             [recompute_prepare]: 0.000185091
#             [updatestate_depend_eliminate]: 0.00091267
#             [updatestate_assign_eliminate]: 0.000138598
#             [updatestate_loads_eliminate]: 0.000231015
#             [parameter_eliminate]: 4.61563e-06
#             [a_2]: 0.00301971
#             [accelerated_algorithm]: 7.4584e-05
#             [auto_parallel]: 1.59573e-05
#             [parallel]: 4.46476e-06
#             [allreduce_fusion]: 5.90365e-05
#             [virtual_dataset]: 6.96778e-05
#             [virtual_output]: 6.40191e-05
#             [shard]: 0.000393843
#             [meta_fg_expand]: 0.236792, [15]
#                 [Cycle 1]: 0.0220363, [1]
#                     [resolve]: 0.0220232
#                 [Cycle 1]: 0.000422692, [1]
#                     [resolve]: 0.000416368
#                 [Cycle 1]: 0.00478391, [1]
#                     [resolve]: 0.00477035
#                 [Cycle 1]: 0.0213941, [1]
#                     [resolve]: 0.0213838
#                 [Cycle 1]: 0.000241611, [1]
#                     [resolve]: 0.000231056
#                 [Cycle 1]: 0.000510424, [1]
#                     [resolve]: 0.00050438
#                 [Cycle 1]: 0.00202372, [1]
#                     [resolve]: 0.00201746
#                 [Cycle 1]: 0.000532316, [1]
#                     [resolve]: 0.000526428
#                 [Cycle 1]: 0.000400469, [1]
#                     [resolve]: 0.000393521
#                 [Cycle 1]: 0.000521716, [1]
#                     [resolve]: 0.000515658
#                 [Cycle 1]: 0.000213275, [1]
#                     [resolve]: 0.000207927
#                 [Cycle 1]: 0.000848418, [1]
#                     [resolve]: 0.000837462
#                 [Cycle 1]: 0.000533709, [1]
#                     [resolve]: 0.000527371
#                 [Cycle 1]: 0.000772769, [1]
#                     [resolve]: 0.000766415
#                 [Cycle 1]: 0.000720536, [1]
#                     [resolve]: 0.000714228
#             [after_resolve]: 0.00194852
#             [a_after_grad]: 0.00637677
#             [renormalize]: 0.179476
#             [real_op_eliminate]: 0.00133611
#             [auto_monad_grad]: 0.00084406
#             [auto_monad_eliminator]: 0.00189774
#             [cse]: 0.00404305
#             [a_3]: 0.0167491
#         [Cycle 2]: 0.0536505, [25]
#             [expand_dump_flag]: 2.33557e-05
#             [switch_simplify]: 0.0015873
#             [a_1]: 0.0217121
#             [recompute_prepare]: 9.06792e-05
#             [updatestate_depend_eliminate]: 0.000108108
#             [updatestate_assign_eliminate]: 8.06898e-05
#             [updatestate_loads_eliminate]: 0.000135813
#             [parameter_eliminate]: 2.81073e-06
#             [a_2]: 0.00373107
#             [accelerated_algorithm]: 0.000112856
#             [auto_parallel]: 7.06874e-06
#             [parallel]: 3.55393e-06
#             [allreduce_fusion]: 9.41232e-05
#             [virtual_dataset]: 0.000103036
#             [virtual_output]: 0.00010745
#             [shard]: 0.000282144
#             [meta_fg_expand]: 0.000202814
#             [after_resolve]: 8.41841e-05
#             [a_after_grad]: 0.000121107
#             [renormalize]: 0.0223887
#             [real_op_eliminate]: 0.000119487
#             [auto_monad_grad]: 4.67338e-06
#             [auto_monad_eliminator]: 0.000403123
#             [cse]: 0.000993617
#             [a_3]: 0.0010701
#         [Cycle 3]: 0.0119712, [25]
#             [expand_dump_flag]: 1.61864e-06
#             [switch_simplify]: 0.000104679
#             [a_1]: 0.00182041
#             [recompute_prepare]: 7.19652e-05
#             [updatestate_depend_eliminate]: 7.68267e-05
#             [updatestate_assign_eliminate]: 6.76773e-05
#             [updatestate_loads_eliminate]: 7.74376e-05
#             [parameter_eliminate]: 2.12528e-06
#             [a_2]: 0.00168798
#             [accelerated_algorithm]: 0.000109844
#             [auto_parallel]: 6.69621e-06
#             [parallel]: 2.90759e-06
#             [allreduce_fusion]: 4.97121e-05
#             [virtual_dataset]: 0.000101313
#             [virtual_output]: 9.32217e-05
#             [shard]: 0.000145905
#             [meta_fg_expand]: 0.000136634
#             [after_resolve]: 7.66125e-05
#             [a_after_grad]: 0.000113595
#             [renormalize]: 0.00497416
#             [real_op_eliminate]: 0.000103364
#             [auto_monad_grad]: 2.5034e-06
#             [auto_monad_eliminator]: 0.00026444
#             [cse]: 0.000787228
#             [a_3]: 0.00102946
#         [Cycle 4]: 0.00624386, [25]
#             [expand_dump_flag]: 8.62405e-07
#             [switch_simplify]: 0.000104204
#             [a_1]: 0.00166269
#             [recompute_prepare]: 6.98175e-05
#             [updatestate_depend_eliminate]: 6.2352e-05
#             [updatestate_assign_eliminate]: 6.56396e-05
#             [updatestate_loads_eliminate]: 6.60866e-05
#             [parameter_eliminate]: 1.49943e-06
#             [a_2]: 0.00170403
#             [accelerated_algorithm]: 0.000101322
#             [auto_parallel]: 2.34134e-06
#             [parallel]: 1.8198e-06
#             [allreduce_fusion]: 4.54113e-05
#             [virtual_dataset]: 9.08524e-05
#             [virtual_output]: 9.71537e-05
#             [shard]: 0.000117034
#             [meta_fg_expand]: 0.000140272
#             [after_resolve]: 7.65547e-05
#             [a_after_grad]: 0.000112893
#             [renormalize]: 1.82539e-07
#             [real_op_eliminate]: 8.90158e-05
#             [auto_monad_grad]: 1.46031e-06
#             [auto_monad_eliminator]: 0.000239789
#             [cse]: 0.000302751
#             [a_3]: 0.00102557
#     [clean_after_opta]: 8.66055e-05
#     [opt_b]: 0.00316526, [1]
#         [Cycle 1]: 0.00316077, [7]
#             [b_1]: 0.00253291
#             [b_2]: 8.82056e-05
#             [updatestate_depend_eliminate]: 6.19907e-05
#             [updatestate_assign_eliminate]: 7.47479e-05
#             [updatestate_loads_eliminate]: 6.76978e-05
#             [renormalize]: 4.04194e-07
#             [cse]: 0.000318313
#     [cconv]: 5.78333e-05
#     [opt_after_cconv]: 0.000821499, [1]
#         [Cycle 1]: 0.000817604, [6]
#             [c_1]: 0.000283096
#             [updatestate_depend_eliminate]: 6.18063e-05
#             [updatestate_assign_eliminate]: 6.5051e-05
#             [updatestate_loads_eliminate]: 6.6068e-05
#             [cse]: 0.000329595
#             [renormalize]: 3.53903e-07
#     [remove_dup_value]: 0.00138391
#     [tuple_transform]: 0.000524271, [1]
#         [Cycle 1]: 0.000520421, [2]
#             [d_1]: 0.000515062
#             [renormalize]: 3.46452e-07
#     [add_cache_embedding]: 0.000151109
#     [add_recomputation]: 0.000637276
#     [cse_after_recomputation]: 0.000254815, [1]
#         [Cycle 1]: 0.00025057, [1]
#             [cse]: 0.000246888
#     [environ_conv]: 0.000108015
#     [slice_recompute_activation]: 1.95764e-06
#     [comm_op_add_attrs]: 3.23541e-06
#     [add_comm_op_reuse_tag]: 7.00355e-07
# [py_opt]: 2.15322e-06
# [auto_monad_reorder]: 0.000384828
# [eliminate_forward_cnode]: 5.06639e-07
# [eliminate_ad_related_special_op_node]: 0.000452211
# [validate]: 0.000226725
# [distribtued_split]: 9.574e-07
# [task_emit]: 0.0696655
# [execute]: 6.46152e-06
# Sums
#     parse                                :     0.005467s :  0.40%
#     symbol_resolve.resolve               :     0.306278s : 22.50%
#     combine_like_graphs                  :     0.000001s :  0.00%
#     inference_opt_prepare                :     0.002338s :  0.17%
#     abstract_specialize                  :     0.597489s : 43.89%
#     auto_monad                           :     0.002728s :  0.20%
#     inline                               :     0.000013s :  0.00%
#     py_pre_ad                            :     0.000002s :  0.00%
#     pynative_shard                       :     0.000002s :  0.00%
#     pipeline_split                       :     0.000010s :  0.00%
#     optimize.simplify_data_structures    :     0.001245s :  0.09%
#     optimize.opt_a.expand_dump_flag      :     0.000054s :  0.00%
#     optimize.opt_a.switch_simplify       :     0.003429s :  0.25%
#     optimize.opt_a.a_1                   :     0.046209s :  3.39%
#     optimize.opt_a.recompute_prepare     :     0.000418s :  0.03%
#     optimize.opt_a.updatestate_depend_eliminate :     0.001160s :  0.09%
#     optimize.opt_a.updatestate_assign_eliminate :     0.000353s :  0.03%
#     optimize.opt_a.updatestate_loads_eliminate :     0.000510s :  0.04%
#     optimize.opt_a.parameter_eliminate   :     0.000011s :  0.00%
#     optimize.opt_a.a_2                   :     0.010143s :  0.74%
#     optimize.opt_a.accelerated_algorithm :     0.000399s :  0.03%
#     optimize.opt_a.auto_parallel         :     0.000032s :  0.00%
#     optimize.opt_a.parallel              :     0.000013s :  0.00%
#     optimize.opt_a.allreduce_fusion      :     0.000248s :  0.02%
#     optimize.opt_a.virtual_dataset       :     0.000365s :  0.03%
#     optimize.opt_a.virtual_output        :     0.000362s :  0.03%
#     optimize.opt_a.shard                 :     0.000939s :  0.07%
#     optimize.opt_a.meta_fg_expand        :     0.000480s :  0.04%
#     optimize.opt_a.meta_fg_expand.resolve :     0.055836s :  4.10%
#     optimize.opt_a.after_resolve         :     0.002186s :  0.16%
#     optimize.opt_a.a_after_grad          :     0.006724s :  0.49%
#     optimize.opt_a.renormalize           :     0.206839s : 15.19%
#     optimize.opt_a.real_op_eliminate     :     0.001648s :  0.12%
#     optimize.opt_a.auto_monad_grad       :     0.000853s :  0.06%
#     optimize.opt_a.auto_monad_eliminator :     0.002805s :  0.21%
#     optimize.opt_a.cse                   :     0.006127s :  0.45%
#     optimize.opt_a.a_3                   :     0.019874s :  1.46%
#     optimize.clean_after_opta            :     0.000087s :  0.01%
#     optimize.opt_b.b_1                   :     0.002533s :  0.19%
#     optimize.opt_b.b_2                   :     0.000088s :  0.01%
#     optimize.opt_b.updatestate_depend_eliminate :     0.000062s :  0.00%
#     optimize.opt_b.updatestate_assign_eliminate :     0.000075s :  0.01%
#     optimize.opt_b.updatestate_loads_eliminate :     0.000068s :  0.00%
#     optimize.opt_b.renormalize           :     0.000000s :  0.00%
#     optimize.opt_b.cse                   :     0.000318s :  0.02%
#     optimize.cconv                       :     0.000058s :  0.00%
#     optimize.opt_after_cconv.c_1         :     0.000283s :  0.02%
#     optimize.opt_after_cconv.updatestate_depend_eliminate :     0.000062s :  0.00%
#     optimize.opt_after_cconv.updatestate_assign_eliminate :     0.000065s :  0.00%
#     optimize.opt_after_cconv.updatestate_loads_eliminate :     0.000066s :  0.00%
#     optimize.opt_after_cconv.cse         :     0.000330s :  0.02%
#     optimize.opt_after_cconv.renormalize :     0.000000s :  0.00%
#     optimize.remove_dup_value            :     0.001384s :  0.10%
#     optimize.tuple_transform.d_1         :     0.000515s :  0.04%
#     optimize.tuple_transform.renormalize :     0.000000s :  0.00%
#     optimize.add_cache_embedding         :     0.000151s :  0.01%
#     optimize.add_recomputation           :     0.000637s :  0.05%
#     optimize.cse_after_recomputation.cse :     0.000247s :  0.02%
#     optimize.environ_conv                :     0.000108s :  0.01%
#     optimize.slice_recompute_activation  :     0.000002s :  0.00%
#     optimize.comm_op_add_attrs           :     0.000003s :  0.00%
#     optimize.add_comm_op_reuse_tag       :     0.000001s :  0.00%
#     py_opt                               :     0.000002s :  0.00%
#     auto_monad_reorder                   :     0.000385s :  0.03%
#     eliminate_forward_cnode              :     0.000001s :  0.00%
#     eliminate_ad_related_special_op_node :     0.000452s :  0.03%
#     validate                             :     0.000227s :  0.02%
#     distribtued_split                    :     0.000001s :  0.00%
#     task_emit                            :     0.069666s :  5.12%
#     execute                              :     0.000006s :  0.00%
#
# Time group info:
# ------[substitution.]   0.362556  8315
#  0.01% :     0.000045s :     28: substitution.addn_check_dump
#  0.05% :     0.000177s :     32: substitution.addn_zero_filter
#  0.01% :     0.000041s :     26: substitution.adjust_all_reduce_mul_add
#  0.23% :     0.000821s :    222: substitution.arithmetic_simplify
#  0.07% :     0.000236s :    180: substitution.arithmetic_simplify2
#  0.02% :     0.000059s :     72: substitution.depend_value_elim
#  0.00% :     0.000011s :      3: substitution.environ_get_add_eliminate
#  0.00% :     0.000008s :      2: substitution.environ_get_depend_swap
#  0.00% :     0.000007s :      5: substitution.environ_get_eliminate
#  0.00% :     0.000016s :      3: substitution.environ_get_set_eliminate
#  0.00% :     0.000015s :     15: substitution.float_depend_g_call
#  0.00% :     0.000014s :      2: substitution.float_environ_get_switch
#  0.01% :     0.000033s :     41: substitution.float_tuple_getitem_switch
# 93.39% :     0.338580s :   1103: substitution.getattr_resolve
#  0.03% :     0.000101s :    181: substitution.graph_param_transform
#  0.00% :     0.000005s :      4: substitution.incorporate_call
#  0.00% :     0.000002s :      4: substitution.incorporate_call_switch
#  0.00% :     0.000006s :      2: substitution.incorporate_environ_get
#  0.00% :     0.000003s :      2: substitution.incorporate_environ_get_switch
#  0.00% :     0.000013s :     36: substitution.incorporate_getitem_set
#  4.58% :     0.016596s :   1185: substitution.inline
#  0.01% :     0.000019s :     60: substitution.less_batch_normalization
#  0.01% :     0.000038s :    126: substitution.load_eliminater
#  0.02% :     0.000067s :     29: substitution.merge_addn
#  0.21% :     0.000747s :   1039: substitution.meta_fg_var_prepare
#  0.04% :     0.000154s :    183: substitution.minmaximum_grad
#  0.01% :     0.000019s :     15: substitution.partial_eliminate
#  0.02% :     0.000074s :     64: substitution.real_op_eliminate
#  0.11% :     0.000401s :     63: substitution.reduce_eliminate
#  0.17% :     0.000598s :    712: substitution.replace_applicator
#  0.05% :     0.000182s :    539: substitution.replace_old_param
#  0.03% :     0.000124s :     49: substitution.reshape_eliminate
#  0.00% :     0.000011s :      2: substitution.set_cell_output_no_recompute
#  0.00% :     0.000017s :      2: substitution.specialize_transform
#  0.01% :     0.000022s :     18: substitution.split_environ_get_set_with_tuple_value
#  0.04% :     0.000142s :    148: substitution.switch_simplify
#  0.01% :     0.000027s :     16: substitution.tile_eliminate
#  0.01% :     0.000033s :     16: substitution.transpose_eliminate
#  0.15% :     0.000535s :    196: substitution.tuple_list_convert_item_index_to_positive
#  0.06% :     0.000223s :    224: substitution.tuple_list_get_item_const_eliminator
#  0.10% :     0.000366s :    221: substitution.tuple_list_get_item_depend_reorder
#  0.26% :     0.000941s :    528: substitution.tuple_list_get_item_eliminator
#  0.08% :     0.000304s :    224: substitution.tuple_list_get_set_item_eliminator
#  0.01% :     0.000026s :      5: substitution.tuple_list_set_item_eliminator
#  0.08% :     0.000283s :    324: substitution.updatestate_pure_node_eliminater
#  0.11% :     0.000387s :    362: substitution.updatestate_useless_node_eliminater
#  0.01% :     0.000027s :      2: substitution.value_based_eliminate
# ------[renormalize.]   0.206815     6
# 75.11% :     0.155344s :      3: renormalize.infer
# 24.89% :     0.051471s :      3: renormalize.specialize
# ------[replace.]   0.021906  2173
#  0.26% :     0.000056s :      6: replace.addn_zero_filter
#  0.35% :     0.000077s :     10: replace.arithmetic_simplify
#  0.63% :     0.000137s :     28: replace.depend_value_elim
#  0.58% :     0.000127s :      1: replace.environ_get_set_eliminate
# 54.07% :     0.011845s :    938: replace.getattr_resolve
# 19.79% :     0.004336s :    627: replace.inline
#  0.06% :     0.000014s :      1: replace.merge_addn
#  0.64% :     0.000141s :      1: replace.meta_fg_var_prepare
#  0.04% :     0.000010s :      1: replace.partial_eliminate
#  1.42% :     0.000312s :     64: replace.real_op_eliminate
#  0.08% :     0.000017s :      2: replace.reduce_eliminate
#  1.50% :     0.000328s :     37: replace.replace_applicator
#  0.17% :     0.000037s :      6: replace.reshape_eliminate
#  5.72% :     0.001253s :    148: replace.switch_simplify
#  1.06% :     0.000232s :     28: replace.tuple_list_get_item_depend_reorder
# 13.32% :     0.002917s :    268: replace.tuple_list_get_item_eliminator
#  0.10% :     0.000023s :      3: replace.tuple_list_get_set_item_eliminator
#  0.13% :     0.000029s :      2: replace.tuple_list_set_item_eliminator
#  0.08% :     0.000017s :      2: replace.updatestate_useless_node_eliminater
# ------[match.]   0.352446  2173
#  0.00% :     0.000017s :      6: match.addn_zero_filter
#  0.03% :     0.000096s :     10: match.arithmetic_simplify
#  0.00% :     0.000015s :     28: match.depend_value_elim
#  0.00% :     0.000013s :      1: match.environ_get_set_eliminate
# 95.97% :     0.338239s :    938: match.getattr_resolve
#  3.65% :     0.012879s :    627: match.inline
#  0.00% :     0.000013s :      1: match.merge_addn
#  0.01% :     0.000047s :      1: match.meta_fg_var_prepare
#  0.00% :     0.000003s :      1: match.partial_eliminate
#  0.02% :     0.000074s :     64: match.real_op_eliminate
#  0.05% :     0.000193s :      2: match.reduce_eliminate
#  0.02% :     0.000060s :     37: match.replace_applicator
#  0.00% :     0.000015s :      6: match.reshape_eliminate
#  0.04% :     0.000142s :    148: match.switch_simplify
#  0.03% :     0.000106s :     28: match.tuple_list_get_item_depend_reorder
#  0.14% :     0.000502s :    268: match.tuple_list_get_item_eliminator
#  0.00% :     0.000009s :      3: match.tuple_list_get_set_item_eliminator
#  0.00% :     0.000009s :      2: match.tuple_list_set_item_eliminator
#  0.00% :     0.000015s :      2: match.updatestate_useless_node_eliminater
# ------[func_graph_cloner_run.]   0.171675  1669
# 86.42% :     0.148357s :    929: func_graph_cloner_run.FuncGraphClonerGraph
#  1.93% :     0.003306s :     38: func_graph_cloner_run.FuncGraphClonerNode
# 11.66% :     0.020012s :    702: func_graph_cloner_run.FuncGraphSpecializer
# ------[meta_graph.]   0.000000     0
# ------[manager.]   0.000000     0
# ------[pynative]   0.000000     0
# ------[others.]   0.457795   270
#  6.53% :     0.029914s :    169: opt.transform.opt_a
#  0.55% :     0.002519s :     28: opt.transform.opt_b
# 78.72% :     0.360374s :     32: opt.transform.opt_resolve
#  0.02% :     0.000108s :      1: opt.transforms.ad_related_special_op_eliminate
#  0.51% :     0.002322s :      1: opt.transforms.inference_prepare
# 13.47% :     0.061679s :     36: opt.transforms.opt_a
#  0.06% :     0.000281s :      1: opt.transforms.opt_after_cconv
#  0.02% :     0.000086s :      1: opt.transforms.opt_b
#  0.11% :     0.000513s :      1: opt.transforms.opt_trans_graph
# Step: 0, E_pot: 3.2556585e-05, E_kin: 40.248314, E_tot: 40.24835, Temperature: 1613.5865
# Step: 10, E_pot: 2.172965, E_kin: 34.174595, E_tot: 36.34756, Temperature: 1370.0864
# Step: 20, E_pot: 4.137269, E_kin: 31.638657, E_tot: 35.775925, Temperature: 1268.4186
# Step: 30, E_pot: 10.337389, E_kin: 23.725569, E_tot: 34.062958, Temperature: 951.1767
# Step: 40, E_pot: 12.004141, E_kin: 22.491926, E_tot: 34.496067, Temperature: 901.719
# Step: 50, E_pot: 18.843906, E_kin: 15.537665, E_tot: 34.381573, Temperature: 622.9172
# Step: 60, E_pot: 18.82572, E_kin: 15.850073, E_tot: 34.675793, Temperature: 635.4419
# Step: 70, E_pot: 24.135715, E_kin: 11.445822, E_tot: 35.581535, Temperature: 458.872
# Step: 80, E_pot: 23.134079, E_kin: 12.1947, E_tot: 35.32878, Temperature: 488.8951
# Step: 90, E_pot: 26.383478, E_kin: 10.739815, E_tot: 37.12329, Temperature: 430.5676
# Step: 100, E_pot: 26.653126, E_kin: 10.448051, E_tot: 37.101177, Temperature: 418.8706
# Step: 110, E_pot: 27.789162, E_kin: 12.133141, E_tot: 39.922302, Temperature: 486.42715
# Step: 120, E_pot: 29.090027, E_kin: 11.903717, E_tot: 40.993744, Temperature: 477.22937
# Step: 130, E_pot: 26.897621, E_kin: 16.639034, E_tot: 43.536655, Temperature: 667.07196
# Step: 140, E_pot: 27.14367, E_kin: 17.235687, E_tot: 44.379356, Temperature: 690.99225
# Step: 150, E_pot: 23.052807, E_kin: 21.452068, E_tot: 44.504875, Temperature: 860.0303
# Step: 160, E_pot: 23.536364, E_kin: 20.56404, E_tot: 44.100403, Temperature: 824.42847
# Step: 170, E_pot: 21.954666, E_kin: 20.414968, E_tot: 42.369637, Temperature: 818.4521
# Step: 180, E_pot: 23.93132, E_kin: 18.582098, E_tot: 42.51342, Temperature: 744.97095
# Step: 190, E_pot: 25.684296, E_kin: 15.809905, E_tot: 41.4942, Temperature: 633.83154
# Step: 200, E_pot: 25.495064, E_kin: 17.724733, E_tot: 43.219795, Temperature: 710.5985
# Step: 210, E_pot: 27.545448, E_kin: 15.888008, E_tot: 43.433456, Temperature: 636.96277
# Step: 220, E_pot: 22.362818, E_kin: 22.528366, E_tot: 44.891182, Temperature: 903.1799
# Step: 230, E_pot: 24.30133, E_kin: 20.8835, E_tot: 45.18483, Temperature: 837.2359
# Step: 240, E_pot: 17.013449, E_kin: 27.792084, E_tot: 44.805534, Temperature: 1114.2064
# Step: 250, E_pot: 20.935965, E_kin: 24.143467, E_tot: 45.07943, Temperature: 967.93054
# Step: 260, E_pot: 16.27917, E_kin: 27.164104, E_tot: 43.443275, Temperature: 1089.0304
# Step: 270, E_pot: 22.54371, E_kin: 22.141068, E_tot: 44.684776, Temperature: 887.65283
# Step: 280, E_pot: 22.11915, E_kin: 21.728605, E_tot: 43.847755, Temperature: 871.1169
# Step: 290, E_pot: 27.3411, E_kin: 19.442898, E_tot: 46.783997, Temperature: 779.4811
# Step: 300, E_pot: 27.26812, E_kin: 20.50407, E_tot: 47.77219, Temperature: 822.0243
# Step: 310, E_pot: 26.27055, E_kin: 24.332901, E_tot: 50.60345, Temperature: 975.5251
# Step: 320, E_pot: 22.194448, E_kin: 29.024017, E_tot: 51.218468, Temperature: 1163.5956
# Step: 330, E_pot: 15.267702, E_kin: 35.526688, E_tot: 50.794388, Temperature: 1424.2928
# Step: 340, E_pot: 9.697537, E_kin: 39.217854, E_tot: 48.91539, Temperature: 1572.2745
# Step: 350, E_pot: 3.4644842, E_kin: 41.73575, E_tot: 45.200233, Temperature: 1673.2189
# Step: 360, E_pot: 1.9687537, E_kin: 40.58518, E_tot: 42.553932, Temperature: 1627.0917
# Step: 370, E_pot: 1.0886577, E_kin: 37.374557, E_tot: 38.463215, Temperature: 1498.3755
# Step: 380, E_pot: 3.8051498, E_kin: 33.83551, E_tot: 37.64066, Temperature: 1356.4922
# Step: 390, E_pot: 7.3330626, E_kin: 27.70441, E_tot: 35.03747, Temperature: 1110.6915
# Step: 400, E_pot: 10.441173, E_kin: 25.35717, E_tot: 35.798344, Temperature: 1016.58887
# Step: 410, E_pot: 15.559087, E_kin: 19.079685, E_tot: 34.63877, Temperature: 764.9196
# Step: 420, E_pot: 16.755882, E_kin: 18.81453, E_tot: 35.57041, Temperature: 754.28925
# Step: 430, E_pot: 21.183466, E_kin: 14.191988, E_tot: 35.375454, Temperature: 568.96796
# Step: 440, E_pot: 20.609022, E_kin: 15.167974, E_tot: 35.776997, Temperature: 608.09607
# Step: 450, E_pot: 24.00513, E_kin: 12.422938, E_tot: 36.42807, Temperature: 498.04535
# Step: 460, E_pot: 23.683292, E_kin: 13.075178, E_tot: 36.75847, Temperature: 524.19415
# Step: 470, E_pot: 26.576244, E_kin: 12.484023, E_tot: 39.06027, Temperature: 500.49432
# Step: 480, E_pot: 26.864824, E_kin: 13.410428, E_tot: 40.275253, Temperature: 537.63464
# Step: 490, E_pot: 26.864265, E_kin: 16.852133, E_tot: 43.7164, Temperature: 675.6153
# Step: 500, E_pot: 25.56058, E_kin: 19.394379, E_tot: 44.954956, Temperature: 777.5359
# Step: 510, E_pot: 21.166742, E_kin: 25.254051, E_tot: 46.42079, Temperature: 1012.45483
# Step: 520, E_pot: 18.662706, E_kin: 27.273813, E_tot: 45.93652, Temperature: 1093.4287
# Step: 530, E_pot: 14.0146055, E_kin: 30.004057, E_tot: 44.01866, Temperature: 1202.8862
# Step: 540, E_pot: 13.447736, E_kin: 29.001896, E_tot: 42.44963, Temperature: 1162.7087
# Step: 550, E_pot: 12.468113, E_kin: 27.18396, E_tot: 39.652073, Temperature: 1089.8264
# Step: 560, E_pot: 13.648407, E_kin: 25.5468, E_tot: 39.195206, Temperature: 1024.1913
# Step: 570, E_pot: 14.458421, E_kin: 23.176952, E_tot: 37.635372, Temperature: 929.18225
# Step: 580, E_pot: 13.770885, E_kin: 24.693966, E_tot: 38.46485, Temperature: 990.00055
# Step: 590, E_pot: 13.999901, E_kin: 23.383766, E_tot: 37.383667, Temperature: 937.4736
# Step: 600, E_pot: 10.667676, E_kin: 27.215115, E_tot: 37.88279, Temperature: 1091.0753
# Step: 610, E_pot: 11.983607, E_kin: 24.377844, E_tot: 36.36145, Temperature: 977.3269
# Step: 620, E_pot: 9.103281, E_kin: 26.651308, E_tot: 35.75459, Temperature: 1068.4718
# Step: 630, E_pot: 13.976988, E_kin: 20.41688, E_tot: 34.393867, Temperature: 818.52875
# Step: 640, E_pot: 14.858825, E_kin: 18.926252, E_tot: 33.785076, Temperature: 758.7683
# Step: 650, E_pot: 23.007645, E_kin: 11.298285, E_tot: 34.30593, Temperature: 452.95712
# Step: 660, E_pot: 26.898262, E_kin: 8.848124, E_tot: 35.746384, Temperature: 354.7282
# Step: 670, E_pot: 33.458015, E_kin: 5.5725355, E_tot: 39.030552, Temperature: 223.40733
# Step: 680, E_pot: 35.07244, E_kin: 7.036831, E_tot: 42.109272, Temperature: 282.1121
# Step: 690, E_pot: 34.28285, E_kin: 11.490738, E_tot: 45.773586, Temperature: 460.67273
# Step: 700, E_pot: 31.423609, E_kin: 16.054136, E_tot: 47.477745, Temperature: 643.623
# Step: 710, E_pot: 24.161463, E_kin: 24.00099, E_tot: 48.162453, Temperature: 962.21857
# Step: 720, E_pot: 21.389168, E_kin: 26.153515, E_tot: 47.542683, Temperature: 1048.515
# Step: 730, E_pot: 14.116707, E_kin: 31.20134, E_tot: 45.318047, Temperature: 1250.8862
# Step: 740, E_pot: 15.5826845, E_kin: 28.997398, E_tot: 44.580082, Temperature: 1162.5284
# Step: 750, E_pot: 12.066586, E_kin: 29.78796, E_tot: 41.854546, Temperature: 1194.2228
# Step: 760, E_pot: 16.336807, E_kin: 26.223982, E_tot: 42.56079, Temperature: 1051.3401
# Step: 770, E_pot: 15.896152, E_kin: 24.609882, E_tot: 40.506035, Temperature: 986.6295
# Step: 780, E_pot: 19.204609, E_kin: 22.91472, E_tot: 42.11933, Temperature: 918.6692
# Step: 790, E_pot: 20.001759, E_kin: 20.703894, E_tot: 40.70565, Temperature: 830.0354
# Step: 800, E_pot: 19.979568, E_kin: 22.01332, E_tot: 41.99289, Temperature: 882.5314
# Step: 810, E_pot: 20.869162, E_kin: 20.113256, E_tot: 40.982418, Temperature: 806.35626
# Step: 820, E_pot: 18.551683, E_kin: 22.72963, E_tot: 41.28131, Temperature: 911.2487
# Step: 830, E_pot: 20.071953, E_kin: 21.028242, E_tot: 41.100197, Temperature: 843.03876
# Step: 840, E_pot: 18.083073, E_kin: 23.196148, E_tot: 41.27922, Temperature: 929.95184
# Step: 850, E_pot: 19.498743, E_kin: 23.066874, E_tot: 42.565617, Temperature: 924.7691
# Step: 860, E_pot: 17.467253, E_kin: 25.518414, E_tot: 42.985664, Temperature: 1023.0533
# Step: 870, E_pot: 16.27659, E_kin: 28.056023, E_tot: 44.33261, Temperature: 1124.7881
# Step: 880, E_pot: 13.669845, E_kin: 29.811586, E_tot: 43.48143, Temperature: 1195.1699
# Step: 890, E_pot: 10.60291, E_kin: 32.220448, E_tot: 42.823357, Temperature: 1291.7432
# Step: 900, E_pot: 10.110571, E_kin: 30.621511, E_tot: 40.732082, Temperature: 1227.6405
# Step: 910, E_pot: 8.335704, E_kin: 30.288744, E_tot: 38.624447, Temperature: 1214.2996
# Step: 920, E_pot: 10.536253, E_kin: 27.074696, E_tot: 37.610947, Temperature: 1085.4458
# Step: 930, E_pot: 10.037347, E_kin: 25.789309, E_tot: 35.826656, Temperature: 1033.9137
# Step: 940, E_pot: 11.272522, E_kin: 25.295721, E_tot: 36.568245, Temperature: 1014.1253
# Step: 950, E_pot: 10.31678, E_kin: 24.75739, E_tot: 35.07417, Temperature: 992.5432
# Step: 960, E_pot: 8.8343315, E_kin: 27.203072, E_tot: 36.037403, Temperature: 1090.5925
# Step: 970, E_pot: 8.644094, E_kin: 25.41109, E_tot: 34.055183, Temperature: 1018.7506
# Step: 980, E_pot: 6.7309027, E_kin: 27.45089, E_tot: 34.181793, Temperature: 1100.5277
# Step: 990, E_pot: 10.07566, E_kin: 22.06076, E_tot: 32.13642, Temperature: 884.4332

# %% [markdown]
# 上述运行结果的轨迹输出如下图所示，该结果展示使用了VMD-h5mdplugin插件，在VMD中对分子运行轨迹进行了可视化。
#
# ![](./docs/tutorial_b01.gif)
